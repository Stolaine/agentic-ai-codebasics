# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
llm_gemini_25_flash = ChatGoogleGenerativeAI(model = 'gemini-2.5-flash')

# %%
with open("blood_work.txt", "r") as f:
    blood_report = f.read()

# %%
print(blood_report[:200])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5–17.5)
# Hematocrit:        44%

# %%
extraction_prompt = f"""
You are a medical data extraction assistant.

From the blood report below, extract ALL test values and classify each one as HIGH, LOW, or NORMAL
base don the reference ranges provided in the report.

Format your response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range

Blood Report:
{blood_report}
"""

# %%
print(extraction_prompt)
# Out:
# You are a medical data extraction assistant.
#
# From the blood report below, extract ALL test values and classify each one as HIGH, LOW, or NORMAL
# base don the reference ranges provided in the report.
#
# Format your response as:
# - Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range
#
# Blood Report:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5–17.5)
# Hematocrit:        44%              (Normal: 41–53%)
# WBC:               6.8 x10^3/uL     (Normal: 4.5–11.0)
# Platelets:         220 x10^3/uL     (Normal: 150–400)
#
# LIPID PANEL
# -----------
# Total Cholesterol: 238 mg/dL        (Normal: <200)
# LDL Cholesterol:   162 mg/dL        (Normal: <100)
# HDL Cholesterol:   36 mg/dL         (Normal: >40)
# Triglycerides:     188 mg/dL        (Normal: <150)
#
# METABOLIC PANEL
# ---------------
# Glucose (Fasting): 92 mg/dL         (Normal: 70–99)
# HbA1c:             5.3%             (Normal: <5.7%)
# Creatinine:        1.0 mg/dL        (Normal: 0.7–1.3)
# eGFR:              82 mL/min        (Normal: >60)
#
# LIVER FUNCTION
# --------------
# ALT:               28 U/L           (Normal: 7–40)
# AST:               25 U/L           (Normal: 10–40)
# Bilirubin Total:   0.8 mg/dL        (Normal: 0.2–1.2)
#
# Reviewing Physician: Dr. Priya Nair

# %%
extraction_response = llm_gemini_25_flash.invoke(extraction_prompt)
extracted_value = extraction_response.text

# %%
print("=== STAGE 1: EXTRACTED VALUES ===")
print(extracted_value)
# Out:
# === STAGE 1: EXTRACTED VALUES ===
# Here are the extracted test values and their classifications:
#
# *   Hemoglobin: 15.1 g/dL | Status: NORMAL | Reference: 13.5–17.5
# *   Hematocrit: 44% | Status: NORMAL | Reference: 41–53%
# *   WBC: 6.8 x10^3/uL | Status: NORMAL | Reference: 4.5–11.0
# *   Platelets: 220 x10^3/uL | Status: NORMAL | Reference: 150–400
# *   Total Cholesterol: 238 mg/dL | Status: HIGH | Reference: <200
# *   LDL Cholesterol: 162 mg/dL | Status: HIGH | Reference: <100
# *   HDL Cholesterol: 36 mg/dL | Status: LOW | Reference: >40
# *   Triglycerides: 188 mg/dL | Status: HIGH | Reference: <150
# *   Glucose (Fasting): 92 mg/dL | Status: NORMAL | Reference: 70–99
# *   HbA1c: 5.3% | Status: NORMAL | Reference: <5.7%
# *   Creatinine: 1.0 mg/dL | Status: NORMAL | Reference: 0.7–1.3
# *   eGFR: 82 mL/min | Status: NORMAL | Reference: >60
# *   ALT: 28 U/L | Status: NORMAL | Reference: 7–40
# *   AST: 25 U/L | Status: NORMAL | Reference: 10–40
# *   Bilirubin Total: 0.8 mg/dL | Status: NORMAL | Reference: 0.2–1.2

# %%
diet_prompt = f"""
You are a clinical nutritionist specializing in Indian dietary habits.

Based on the blood work analysis below, write:
1. A short health summary in 3 lines explaining the patient's condition in simple language.
2. A short, practical Indian diet plan having only two sections (1) Foods to avoid (2) Foods to eat more of.

Do not include any other sections in diet plan.

Blood Work Analysis:
{extracted_value}
"""

# %%
print(diet_prompt)
# Out:
# You are a clinical nutritionist specializing in Indian dietary habits.
#
# Based on the blood work analysis below, write:
# 1. A short health summary in 3 lines explaining the patient's condition in simple language.
# 2. A short, practical Indian diet plan having only two sections (1) Foods to avoid (2) Foods to eat more of.
#
# Do not include any other sections in diet plan.
#
# Blood Work Analysis:
# Here are the extracted test values and their classifications:
#
# *   Hemoglobin: 15.1 g/dL | Status: NORMAL | Reference: 13.5–17.5
# *   Hematocrit: 44% | Status: NORMAL | Reference: 41–53%
# *   WBC: 6.8 x10^3/uL | Status: NORMAL | Reference: 4.5–11.0
# *   Platelets: 220 x10^3/uL | Status: NORMAL | Reference: 150–400
# *   Total Cholesterol: 238 mg/dL | Status: HIGH | Reference: <200
# *   LDL Cholesterol: 162 mg/dL | Status: HIGH | Reference: <100
# *   HDL Cholesterol: 36 mg/dL | Status: LOW | Reference: >40
# *   Triglycerides: 188 mg/dL | Status: HIGH | Reference: <150
# *   Glucose (Fasting): 92 mg/dL | Status: NORMAL | Reference: 70–99
# *   HbA1c: 5.3% | Status: NORMAL | Reference: <5.7%
# *   Creatinine: 1.0 mg/dL | Status: NORMAL | Reference: 0.7–1.3
# *   eGFR: 82 mL/min | Status: NORMAL | Reference: >60
# *   ALT: 28 U/L | Status: NORMAL | Reference: 7–40
# *   AST: 25 U/L | Status: NORMAL | Reference: 10–40
# *   Bilirubin Total: 0.8 mg/dL | Status: NORMAL | Reference: 0.2–1.2

# %%
diet_response = llm_gemini_25_flash.invoke(diet_prompt)

# %%
print("=== STAGE 2: HEALTH SUMMARY & DIET PLAN ===")
print(diet_response.text)
# Out:
# === STAGE 2: HEALTH SUMMARY & DIET PLAN ===
# Here is the health summary and diet plan based on your blood work:
#
# **1. Health Summary**
# Your general health, blood counts, and blood sugar levels are currently good. However, your cholesterol and triglyceride levels are elevated, and your "good" cholesterol (HDL) is low. This indicates a need for dietary and lifestyle adjustments to protect your heart health.
#
# **2. Indian Diet Plan**
#
# **Foods to Avoid:**
# *   Deep-fried items like puri, pakoras, samosas, vada, and commercial namkeens.
# *   Excessive ghee, butter, full-fat paneer, full-cream milk, and rich dairy-based gravies.
# *   Red meat (mutton, lamb) and processed meats.
# *   Sugary drinks, excessive sweets (mithai), desserts, and refined flour products (maida-based bread, naan, parotta).
# *   Vanaspati and foods prepared with it.
#
# **Foods to Eat More Of:**
# *   **Whole Grains:** Atta roti, brown rice, oats, jowar, bajra, ragi.
# *   **Fruits & Vegetables:** Plenty of fresh vegetables (especially leafy greens like palak, methi) and 2-3 servings of whole fruits daily.
# *   **Lentils & Legumes:** All types of dal, sprouts, rajma, chana, lobia.
# *   **Lean Protein:** Fish (especially fatty fish like salmon/sardines if available, otherwise local fish), skinned chicken, egg whites, low-fat paneer, tofu.
# *   **Healthy Fats:** A handful of nuts (almonds, walnuts), seeds (flaxseeds, chia seeds), and use olive oil, rice bran oil, or mustard oil in moderation for cooking.
# *   **Low-Fat Dairy:** Skimmed milk, curd (dahi), and buttermilk (chaas).
